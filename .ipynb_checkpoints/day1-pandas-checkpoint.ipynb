# %%
import pandas as pd

a = [1,2,3,4]
var1 = pd.Series(a)

print(var1)

# %%
b = [1,2,3,4]
var = pd.Series(b,dtype=float,index=['a','b','c','d'])
print(var)

# %%
dic = {'Name':['Anand','Sanjay','Vaishu'],'RollNo':[65,56,57]}

var = pd.Series(dic)
print(var)
