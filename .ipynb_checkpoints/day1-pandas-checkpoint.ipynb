# %%
import pandas as pd

a = [1,2,3,4]
var1 = pd.Series(a)

print(var1)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
b = [1,2,3,4]
var = pd.Series(b,dtype=float,index=['a','b','c','d'])
print(var)
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# dtype: float64
